# %% [markdown]
# **Pranay Varma - 2019115067**

# %% [markdown]
# **Importing the required packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **1. Download the dataset**
# **2. Load the dataset**

# %%
filename = "Churn_Modelling.csv"
file = pd.read_csv(filename)

# %% [markdown]
# **3. Perform Below Visualizations.
#     ● Univariate Analysis
#     ● Bi - Variate Analysis
#     ● Multi - Variate Analysis**

# %% [markdown]
# **Univariate Analysis**

# %%
#Univariate Analysis

cols = file.columns
for i in cols:
  try:
     print("\nMean of " , i , " is : ", file[i].mean())
     print("Median of " , i , " is : ", file[i].median())
     #print("Mode of " , i , " is : ", file[i].mode())
  except:
    print("",end = "")
# Out:
# Mean of  RowNumber  is :  5000.5
# Median of  RowNumber  is :  5000.5
#
# Mean of  CustomerId  is :  15690940.5694
# Median of  CustomerId  is :  15690738.0
#
# Mean of  CreditScore  is :  651.0675283037772
# Median of  CreditScore  is :  652.0
#
# Mean of  Age  is :  38.9218
# Median of  Age  is :  37.0
#
# Mean of  Tenure  is :  5.0128
# Median of  Tenure  is :  5.0
#
# Mean of  Balance  is :  76485.889288
# Median of  Balance  is :  97198.54000000001
#
# Mean of  NumOfProducts  is :  1.5302
# Median of  NumOfProducts  is :  1.0
#
# Mean of  HasCrCard  is :  0.7055
# Median of  HasCrCard  is :  1.0
#
# Mean of  IsActiveMember  is :  0.5151
# Median of  IsActiveMember  is :  1.0
#
# Mean of  EstimatedSalary  is :  100090.239881
# Median of  EstimatedSalary  is :  100193.915
#
# Mean of  Exited  is :  0.2037
# Median of  Exited  is :  0.0

# %%
plt.scatter(file["Age"],file["CreditScore"])

# %%
sns.scatterplot(x=file.index,y=file['CreditScore'], hue=file['Balance'])

# %%
sns.barplot(x='Gender',y='EstimatedSalary', data=file)

# %%
pd.plotting.scatter_matrix(file.loc[:, "Gender":"EstimatedSalary"], diagonal ="kde", figsize = (20,15))
plt.show()

# %% [markdown]
# **4. Perform descriptive statistics on the dataset.**

# %%
file.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# **5. Handle the Missing values.**

# %%
file.dropna()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave        619.0    France  Female   42
# 1             2    15647311       Hill        608.0     Spain  Female   41
# 2             3    15619304       Onio        502.0    France  Female   42
# 3             4    15701354       Boni        699.0    France  Female   39
# 4             5    15737888   Mitchell        850.0     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku        771.0    France    Male   39
# 9996       9997    15569892  Johnstone        516.0    France    Male   35
# 9997       9998    15584532        Liu        709.0    France  Female   36
# 9998       9999    15682355  Sabbatini        772.0   Germany    Male   42
# 9999      10000    15628319     Walker        792.0    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# **6. Find the outliers and replace the outliers**

# %% [markdown]
# **Finding the Outliers using a Box Plot**

# %%
sns.boxplot(file['CreditScore'],data=file)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Replacing outlier values with the mode of the column**

# %%
#file_trimmed = file[]
file_trimmed = file.loc[file["CreditScore"] < 400, "CreditScore"] = file["CreditScore"].mode()

# %% [markdown]
# **The distribution after outliers have been replaced**

# %%
sns.boxplot(file["CreditScore"],data = file)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **7. Check for Categorical columns and perform encoding.**

# %%
print(file["Gender"].unique())
print(file["HasCrCard"].unique())
print(file["IsActiveMember"].unique())
print(file["Exited"].unique())
print(file["Geography"].unique())
#print(file["NumOfProducts"].unique())
# Out:
# ['Female' 'Male']
# [1 0]
# [1 0]
# [1 0]
# ['France' 'Spain' 'Germany']

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

file["Gender"] = encoder.fit_transform(file["Gender"])
file["Geography"] = encoder.fit_transform(file["Geography"])

# %% [markdown]
# **8. Split the data into dependent and independent variables.**

# %%
dependent = file["Surname"]
independent = file.drop(columns = ["Surname"],axis = 1)
independent.head()
# Out:
#    RowNumber  CustomerId  CreditScore  Geography  Gender  Age  Tenure  \
# 0          1    15634602        619.0          0       0   42       2
# 1          2    15647311        608.0          2       0   41       1
# 2          3    15619304        502.0          0       0   42       8
# 3          4    15701354        699.0          0       0   39       1
# 4          5    15737888        850.0          2       0   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %% [markdown]
# **9. Scale the independent variables**

# %%
names = independent.columns
names
# Out:
# Index(['RowNumber', 'CustomerId', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
from sklearn.preprocessing import scale
X=scale(independent)
X
# Out:
# array([[-1.73187761, -0.78321342, -0.33422749, ...,  0.97024255,
#          0.02188649,  1.97716468],
#        [-1.7315312 , -0.60653412, -0.44887626, ...,  0.97024255,
#          0.21653375, -0.50577476],
#        [-1.73118479, -0.99588476, -1.55367342, ..., -1.03067011,
#          0.2406869 ,  1.97716468],
#        ...,
#        [ 1.73118479, -1.47928179,  0.60380783, ...,  0.97024255,
#         -1.00864308,  1.97716468],
#        [ 1.7315312 , -0.11935577,  1.26043256, ..., -1.03067011,
#         -0.12523071,  1.97716468],
#        [ 1.73187761, -0.87055909,  1.46888486, ..., -1.03067011,
#         -1.07636976, -0.50577476]])

# %%
x = pd.DataFrame(X,columns = names )
x
# Out:
#       RowNumber  CustomerId  CreditScore  Geography    Gender       Age  \
# 0     -1.731878   -0.783213    -0.334227  -0.901886 -1.095988  0.293517
# 1     -1.731531   -0.606534    -0.448876   1.515067 -1.095988  0.198164
# 2     -1.731185   -0.995885    -1.553673  -0.901886 -1.095988  0.293517
# 3     -1.730838    0.144767     0.499582  -0.901886 -1.095988  0.007457
# 4     -1.730492    0.652659     2.073397   1.515067 -1.095988  0.388871
# ...         ...         ...          ...        ...       ...       ...
# 9995   1.730492   -1.177652     1.250010  -0.901886  0.912419  0.007457
# 9996   1.730838   -1.682806    -1.407757  -0.901886  0.912419 -0.373958
# 9997   1.731185   -1.479282     0.603808  -0.901886 -1.095988 -0.278604
# 9998   1.731531   -0.119356     1.260433   0.306591  0.912419  0.293517
# 9999   1.731878   -0.870559     1.468885  -0.901886 -1.095988 -1.041433
#
#         Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# **10. Split the data into training and testing**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,dependent,test_size=0.2,random_state=0)
print(x_train.head(5))
print(x_test.head(5))
print(y_train.head(5))
print(y_test.head(5))
# Out:
#       RowNumber  CustomerId  CreditScore  Geography    Gender       Age  \
# 7389   0.827747   -0.195066     0.166058   1.515067 -1.095988 -0.469311
# 9275   1.481077    0.810821    -2.335370   0.306591  0.912419  0.293517
# 2995  -0.694379   -1.507642    -1.209727  -0.901886 -1.095988 -0.946079
# 5316   0.109639    1.243462     0.030564   1.515067  0.912419  0.102810
# 356   -1.608556   -1.100775     2.073397   1.515067 -1.095988  1.723821
#
#         Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 7389 -0.004426 -1.225848       0.807737   0.646092       -1.030670
# 9275 -1.387538 -0.012892      -0.911583   0.646092        0.970243
# 2995 -1.041760  0.575076      -0.911583   0.646092       -1.030670
# 5316 -0.004426  0.467955      -0.911583   0.646092       -1.030670
# 356   1.032908  0.806010       0.807737   0.646092        0.970243
#
#       EstimatedSalary    Exited
# 7389         1.108382 -0.505775
# 9275        -0.747592 -0.505775
# ...
